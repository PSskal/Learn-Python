# %% [markdown]
# ## Ejercicios: Tkinter Parte 2

# %% [markdown]
# ### Ejercicio 1
#
# Diseñe el siguiente GUI:
#
# ![ejercicio1.png](attachment:ejercicio1.png)
#
# Y luego agregue la programación necesaria para que al presionar el botón *Calcular* se muestre la distancia entre los 2 puntos tridimensionales cuyas coordenadas (x,y, z) serán ingresadas por teclado. Al presionar el botón *salir* se cerrará la aplicación.

# %%
# ESCRIBA SU CODIGO AQUI

# %% [markdown]
# ### Ejercicio 2
# Diseñe el siguiente GUI:
#
# ![](https://warehouse-camo.ingress.cmh1.psfhosted.org/cb2a3e9b14bbc2b49dcb39eed7749d570cd614a9/68747470733a2f2f757365722d696d616765732e67697468756275736572636f6e74656e742e636f6d2f34363136333535352f36333632383638322d63646132383238302d633564622d313165392d393261342d3434656332636236636366392e706e67)
#
#
# Complete las acciones a realizar al hacer click en "Save". Su programa debe de guardar en un archivo CSV la lista de tareas a realizar o realizadas dependiedo del estado de estas (controladas con el Checkbutton).
#
# Al abrir el programa deberá verificar si existe un archivo llamado "to_do.csv" que contiene una lista de cinco tareas. Si el archivo no existe, deberá crear uno con la siguiente información:
#
#     ID,STATUS,DESCRIPCION
#     1,I,
#     2,I,
#     3,I,
#     4,I,
#     5,I,
#
# Si ha abrio el programa previamente y ha hecho cambios, su archivo tendra infomación como la que muestra en el ejemplo:
#
#     ID,STATUS,DESCRIPCION
#     1,C,Sacar a pasaer al perro
#     2,I,Hacer la tarea del curso
#     3,I,
#     4,I,
#     5,I,
#
# donde el campo `STATUS` indicará con `I` si la tarea esta incompleta o con un `C` si la tarea esta completa. Esta información es reflejo de los campos en la  aplicación de forma tal que se muestren todas las tareas a realizar y su estado. Note que el archivo de muestra solo tiene dos tareas, pero tiene 5 registros y esto siempre será asi.
#
# Si al abrir el programa el archivo existe, leera los estados de sus tareas. Cambie los estados (descripcion, check) y cada vez que haga click en "Save" estos cambios deberían de actualizarse en el archivo. Si cierra su programa y lo vuelve a abrir deberá mostrar la lista de tareas con las últimas modificaciones.

# %%
# ESCRIBA SU CODIGO AQUI
